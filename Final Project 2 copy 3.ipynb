# %%
import os # accessing directory structure
import itertools
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from pandas.plotting import andrews_curves
import plotly.plotly as py
import math
import datetime as dt
from datetime import datetime
from dateutil.parser import parse
#df.to_csv('pandas_dataframe_importing_csv/example.csv') #exporting to csv

# Any results you write to the current directory are saved as output.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    Position                  Track Name         Artist  Streams  \
# 0         1  Reggaetón Lento (Bailemos)           CNCO    19272
# 1         2                    Chantaje        Shakira    19270
# 2         3   Otra Vez (feat. J Balvin)  Zion & Lennox    15761
# 3         4                Vente Pa' Ca   Ricky Martin    14954
# 4         5                      Safari       J Balvin    14269
#
#                                                  URL        Date Region
# 0  https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01     ec
# 1  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01     ec
# 2  https://open.spotify.com/track/3QwBODjSEzelZyV...  2017-01-01     ec
# 3  https://open.spotify.com/track/7DM4BPaS7uofFul...  2017-01-01     ec
# 4  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  2017-01-01     ec

# %%
df['Region'].unique()
# Out:
# array(['ec', 'fr', 'ar', 'fi', 'no', 'it', 'lt', 'ph', 'tw', 'nz', 'ee',
#        'tr', 'us', 'sv', 'cr', 'de', 'cl', 'jp', 'br', 'hn', 'gt', 'ch',
#        'hu', 'ca', 'pe', 'be', 'my', 'dk', 'bo', 'pl', 'at', 'pt', 'se',
#        'mx', 'pa', 'uy', 'is', 'es', 'cz', 'ie', 'nl', 'sk', 'co', 'sg',
#        'id', 'do', 'lu', 'gb', 'global', 'py', 'au', 'lv', 'gr', 'hk'],
#       dtype=object)

# %%
# delete all rows with column 'Region' doesn't have value 'us','mx' - this will allow analysis for only usa, canada and mexico  
indexNames = df[(df['Region'] != 'mx') & (df['Region'] != 'us')].index
df.drop(indexNames , inplace=True)

# %%
df['Region'].unique()
# Out:
# array(['us', 'mx'], dtype=object)

# %%
df.head()
# Out:
#         Position                           Track Name            Artist  \
# 771622         1  Bad and Boujee (feat. Lil Uzi Vert)             Migos
# 771623         2                            Fake Love             Drake
# 771624         3                              Starboy        The Weeknd
# 771625         4                               Closer  The Chainsmokers
# 771626         5                        Black Beatles      Rae Sremmurd
#
#         Streams                                                URL  \
# 771622  1371493  https://open.spotify.com/track/4Km5HrUvYTaSUfi...
# 771623  1180074  https://open.spotify.com/track/343YBumqHu19cGo...
# 771624  1064351  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 771625  1010492  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...
# 771626   874289  https://open.spotify.com/track/6fujklziTHa8uoM...
#
#               Date Region
# 771622  2017-01-01     us
# 771623  2017-01-01     us
# 771624  2017-01-01     us
# ...

# %%
body = client_5a9b711add644eeaaec6c7c5515a60f3.get_object(Bucket='datavisualizationfinalproject-donotdelete-pr-g2yoeodckzrtnh',Key='top2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df2 = pd.read_csv(body)
df2.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
body = client_5a9b711add644eeaaec6c7c5515a60f3.get_object(Bucket='datavisualizationfinalproject-donotdelete-pr-g2yoeodckzrtnh',Key='featuresdf.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df3 = pd.read_csv(body)
df3.head()
# Out:
#                       id                                name  \
# 0  7qiZfU4dY1lWllzX7mPBI                        Shape of You
# 1  5CtI0qwDJkDQGwXD1H1cL                   Despacito - Remix
# 2  4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)
# 3  6RUKPb4LETWmmr3iAEQkt            Something Just Like This
# 4  3DXncPQOG4VBw3QHh3S81                         I'm the One
#
#             artists  danceability  energy   key  loudness  mode  speechiness  \
# 0        Ed Sheeran         0.825   0.652   1.0    -3.183   0.0       0.0802
# 1        Luis Fonsi         0.694   0.815   2.0    -4.328   1.0       0.1200
# 2        Luis Fonsi         0.660   0.786   2.0    -4.757   1.0       0.1700
# 3  The Chainsmokers         0.617   0.635  11.0    -6.769   0.0       0.0317
# 4         DJ Khaled         0.609   0.668   7.0    -4.284   1.0       0.0367
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
df.columns = (df.columns.str.lower()
                .str.replace(' ', '_'))
df.columns
# Out:
# Index(['position', 'track_name', 'artist', 'streams', 'url', 'date', 'region'], dtype='object')

# %%
df.head()
# Out:
#         position                           track_name            artist  \
# 771622         1  Bad and Boujee (feat. Lil Uzi Vert)             Migos
# 771623         2                            Fake Love             Drake
# 771624         3                              Starboy        The Weeknd
# 771625         4                               Closer  The Chainsmokers
# 771626         5                        Black Beatles      Rae Sremmurd
#
#         streams                                                url  \
# 771622  1371493  https://open.spotify.com/track/4Km5HrUvYTaSUfi...
# 771623  1180074  https://open.spotify.com/track/343YBumqHu19cGo...
# 771624  1064351  https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 771625  1010492  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...
# 771626   874289  https://open.spotify.com/track/6fujklziTHa8uoM...
#
#               date region
# 771622  2017-01-01     us
# 771623  2017-01-01     us
# 771624  2017-01-01     us
# ...

# %%
df['region'].unique()
# Out:
# array(['us', 'mx'], dtype=object)

# %%
df['date'] = df['date'].astype('datetime64[ns]')
plt.rcParams["figure.figsize"] = [16,9]
plt.plot(df['date'], df['streams'],'*')
plt.xticks(rotation='vertical')
plt.ylabel('Streams')
plt.xlabel('Dates')
plt.title('Scatterplot of Streams vs Time')
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning:
#
# Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
# Text(0.5, 1.0, 'Scatterplot of Streams vs Time')

# %%
df3.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df3 = df3.rename(columns={'name': 'track_name'})
df3 = df3.drop(columns=['id'])
df3.head()
# Out:
#                            track_name           artists  danceability  energy  \
# 0                        Shape of You        Ed Sheeran         0.825   0.652
# 1                   Despacito - Remix        Luis Fonsi         0.694   0.815
# 2  Despacito (Featuring Daddy Yankee)        Luis Fonsi         0.660   0.786
# 3            Something Just Like This  The Chainsmokers         0.617   0.635
# 4                         I'm the One         DJ Khaled         0.609   0.668
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   1.0    -3.183   0.0       0.0802        0.5810          0.000000
# 1   2.0    -4.328   1.0       0.1200        0.2290          0.000000
# 2   2.0    -4.757   1.0       0.1700        0.2090          0.000000
# 3  11.0    -6.769   0.0       0.0317        0.0498          0.000014
# 4   7.0    -4.284   1.0       0.0367        0.0552          0.000000
#
#    liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
df2.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['position', 'track_name', 'artist', 'streams', 'url', 'date', 'region'], dtype='object')

# %%
df = df.rename(columns={'Track Name': 'track_name'})

# %%
df = df.rename(columns={'track_name': 'Track_Name'})

# %%
df3 = df3.rename(columns={'track_name': 'Track_Name'})

# %%
df2 = df2.rename(columns={'name': 'Track_Name'})

# %%
df.head()
# Out:
#         position                           Track_Name            artist  \
# 771622         1  Bad and Boujee (feat. Lil Uzi Vert)             Migos
# 771623         2                            Fake Love             Drake
# 771624         3                              Starboy        The Weeknd
# 771625         4                               Closer  The Chainsmokers
# 771626         5                        Black Beatles      Rae Sremmurd
#
#         streams                                                url       date  \
# 771622  1371493  https://open.spotify.com/track/4Km5HrUvYTaSUfi... 2017-01-01
# 771623  1180074  https://open.spotify.com/track/343YBumqHu19cGo... 2017-01-01
# 771624  1064351  https://open.spotify.com/track/5aAx2yezTd8zXrk... 2017-01-01
# 771625  1010492  https://open.spotify.com/track/7BKLCZ1jbUBVqRi... 2017-01-01
# 771626   874289  https://open.spotify.com/track/6fujklziTHa8uoM... 2017-01-01
#
#        region
# 771622     us
# 771623     us
# 771624     us
# ...

# %%
df['region'].unique()
# Out:
# array(['us', 'mx'], dtype=object)

# %%
df.describe(include='all')
# Out:
#            position Track_Name  artist       streams  \
# count   148400.0000     148368  148368  1.484000e+05
# unique          NaN       2185     700           NaN
# top             NaN     Closer   Drake           NaN
# freq            NaN        736    3953           NaN
# first           NaN        NaN     NaN           NaN
# last            NaN        NaN     NaN           NaN
# mean       100.5000        NaN     NaN  2.205482e+05
# std         57.7345        NaN     NaN  2.331284e+05
# min          1.0000        NaN     NaN  2.461300e+04
# 25%         50.7500        NaN     NaN  5.634225e+04
# 50%        100.5000        NaN     NaN  1.744565e+05
# 75%        150.2500        NaN     NaN  2.692228e+05
# max        200.0000        NaN     NaN  4.068152e+06
#
#                                                       url  \
# count                                              148400
# unique                                               2617
# ...

# %%
#Below are quick descriptions of the columns to understand the size of our trimmed dataset
df.artist.describe()
# Out:
# count     148368
# unique       700
# top        Drake
# freq        3953
# Name: artist, dtype: object

# %%
#We have 487 unique artists, with Drake being counted the most often.
df.position.describe()
# Out:
# count    148400.0000
# mean        100.5000
# std          57.7345
# min           1.0000
# 25%          50.7500
# 50%         100.5000
# 75%         150.2500
# max         200.0000
# Name: position, dtype: float64

# %%
#We have ~74,000 positions. Since there is a little more than 365 days 
#that the ranking data was collected for the top 200 positions, this makes sense
df.Track_Name.describe()
# Out:
# count     148368
# unique      2185
# top       Closer
# freq         736
# Name: Track_Name, dtype: object

# %%
#We also now know there are 1624 unique track names and Drake's Unforgettable is the most frequency position.

# %%
#Checking on the distribution of the Position to make sure they look like what is expected.
#histogram
sns.distplot(df['position'])

# %%
x = np.log10(df.loc[:,'streams'])
sns.distplot(x, hist=False)

# %%
ax1 = df.plot.scatter(x='position', y='streams', c='DarkBlue')

# %%
sns.jointplot(x='position', y='streams', data=df);

# %%
df['date'].min() #First date entry
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
df['date'].max() #Last date entry
# Out:
# Timestamp('2018-01-09 00:00:00')

# %%
#Using the dates in 2018 as the test set. 
#We will cut these dates off from the training set and store it in dateframe called dftest.
dftest = df[(df['date'] > '2017-12-31')]
df=df[(df['date'] < '2018-01-01')]

# %%
df.tail()
# Out:
#          position                       Track_Name  \
# 2278755       196                    The Scientist
# 2278756       197  Sexto Sentido (feat. Bad Bunny)
# 2278757       198                 Mis Sentimientos
# 2278758       199                  Es Tuyo Mi Amor
# 2278759       200                       Photograph
#
#                                           artist  streams  \
# 2278755                                 Coldplay    40972
# 2278756                         Gigolo Y La Exce    40964
# 2278757                       Los Angeles Azules    40802
# 2278758  Banda Sinaloense MS de Sergio Lizárraga    40437
# 2278759                               Ed Sheeran    40435
#
#                                                        url       date region
# 2278755  https://open.spotify.com/track/75JFxkI2RXiU7L9... 2017-12-31     mx
# 2278756  https://open.spotify.com/track/3iDPALl8BoUbuXZ... 2017-12-31     mx
# ...

# %%
dftest.head()
# Out:
#         position                       Track_Name          artist  streams  \
# 844022         1                         rockstar     Post Malone  1502394
# 844023         2                         No Limit          G-Eazy  1027039
# 844024         3                       Gucci Gang        Lil Pump   930620
# 844025         4  Bartier Cardi (feat. 21 Savage)         Cardi B   877478
# 844026         5                           Havana  Camila Cabello   860232
#
#                                                       url       date region
# 844022  https://open.spotify.com/track/7wGoVu4Dady5GV0... 2018-01-01     us
# 844023  https://open.spotify.com/track/2DQ1ITjI0YoLFzu... 2018-01-01     us
# 844024  https://open.spotify.com/track/43ZyHQITOjhciSU... 2018-01-01     us
# 844025  https://open.spotify.com/track/75FDPwaULRdYDn4... 2018-01-01     us
# 844026  https://open.spotify.com/track/0ofbQMrRDsUaVKq... 2018-01-01     us

# %%
#Here we will combine ranking data with song features. This will give us insight on position and 
#streams related to song qualities. However, be warned that this will drop all track names that are not stored in the features data. 
#We can use this to draw out the list of track names that have reached the top 100 list of 2017.
dfnew = pd.merge(df, df3, on='Track_Name')
dfnew = dfnew.drop(columns=['artists'])
dfnew.sort_values(by='date')
dfnew.head()
# Out:
#    position                           Track_Name artist  streams  \
# 0         1  Bad and Boujee (feat. Lil Uzi Vert)  Migos  1371493
# 1         1  Bad and Boujee (feat. Lil Uzi Vert)  Migos  1161746
# 2         1  Bad and Boujee (feat. Lil Uzi Vert)  Migos  1284891
# 3         1  Bad and Boujee (feat. Lil Uzi Vert)  Migos  1293486
# 4         1  Bad and Boujee (feat. Lil Uzi Vert)  Migos  1295592
#
#                                                  url       date region  \
# 0  https://open.spotify.com/track/4Km5HrUvYTaSUfi... 2017-01-01     us
# 1  https://open.spotify.com/track/4Km5HrUvYTaSUfi... 2017-01-02     us
# 2  https://open.spotify.com/track/4Km5HrUvYTaSUfi... 2017-01-03     us
# 3  https://open.spotify.com/track/4Km5HrUvYTaSUfi... 2017-01-04     us
# 4  https://open.spotify.com/track/4Km5HrUvYTaSUfi... 2017-01-05     us
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# ...

# %%
dfnew['region'].unique()
# Out:
# array(['us', 'mx'], dtype=object)

# %%
df2.columns
# Out:
# Index(['id', 'Track_Name', 'artists', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
#combine features with songs for test data
dftest = pd.merge(dftest, df2, on='Track_Name')
dftest = dftest.drop(columns=['artists'])
dftest.head()
# Out:
#    position Track_Name          artist  streams  \
# 0         5     Havana  Camila Cabello   860232
# 1         8     Havana  Camila Cabello   743162
# 2         8     Havana  Camila Cabello   766533
# 3         8     Havana  Camila Cabello   747263
# 4        10     Havana  Camila Cabello   776759
#
#                                                  url       date region  \
# 0  https://open.spotify.com/track/0ofbQMrRDsUaVKq... 2018-01-01     us
# 1  https://open.spotify.com/track/0ofbQMrRDsUaVKq... 2018-01-02     us
# 2  https://open.spotify.com/track/0ofbQMrRDsUaVKq... 2018-01-03     us
# 3  https://open.spotify.com/track/0ofbQMrRDsUaVKq... 2018-01-04     us
# 4  https://open.spotify.com/track/0ofbQMrRDsUaVKq... 2018-01-05     us
#
#                       id  danceability  energy  ...  loudness  mode  \
# 0  1rfofaqEpACxVEHIZBJe6         0.765   0.523  ...    -4.333   1.0
# 1  1rfofaqEpACxVEHIZBJe6         0.765   0.523  ...    -4.333   1.0
# ...

# %%
dftest.columns
# Out:
# Index(['position', 'Track_Name', 'artist', 'streams', 'url', 'date', 'region',
#        'id', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
dftest = dftest.rename(columns={'track_name': 'Track_Name'})

# %%
dfnew.describe()
# Out:
#            position       streams  danceability       energy           key  \
# count  37495.000000  3.749500e+04  37495.000000  37495.00000  37495.000000
# mean      70.434885  3.322672e+05      0.702395      0.66048      5.285798
# std       55.304752  3.341432e+05      0.120615      0.13537      3.786528
# min        1.000000  2.643100e+04      0.258000      0.34600      0.000000
# 25%       23.000000  9.965650e+04      0.640000      0.55700      1.000000
# 50%       56.000000  2.274170e+05      0.726000      0.66500      6.000000
# 75%      110.000000  4.538490e+05      0.773000      0.78700      8.000000
# max      200.000000  4.068152e+06      0.927000      0.93200     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  37495.000000  37495.000000  37495.000000  37495.000000
# mean      -5.641062      0.601067      0.103516      0.169018
# std        1.794613      0.489686      0.093250      0.169734
# ...

# %%
# find the track names that are in the test set to try and model.
testtn = dftest.Track_Name.unique()

# %%
dftesttn = pd.DataFrame({'track_name': testtn})
print(dftesttn)
# Out:
#                                            track_name
# 0                                              Havana
# 1                     Ric Flair Drip (& Metro Boomin)
# 2                               Him & I (with Halsey)
# 3                                        I Fall Apart
# 4                                  Young Dumb & Broke
# 5                                       XO TOUR Llif3
# 6                                           New Rules
# 7                                         Candy Paint
# 8                                              Wolves
# 9                                             HUMBLE.
# 10                                    Congratulations
# 11                                      Feel It Still
# 12           Meant to Be (feat. Florida Georgia Line)
# 13                                            Silence
# 14  Let Me Go (with Alesso, Florida Georgia Line &...
# 15                                       Let You Down
# ...

# %%
dftesttn = dftesttn.rename(columns={'track_name': 'Track_Name'})

# %%
dftrain = pd.merge(dfnew, dftesttn, on='Track_Name')

dftrain.head()
# Out:
#    position       Track_Name       artist  streams  \
# 0       117  Congratulations  Post Malone   192751
# 1        98  Congratulations  Post Malone   197483
# 2        94  Congratulations  Post Malone   227826
# 3        86  Congratulations  Post Malone   237540
# 4        87  Congratulations  Post Malone   242199
#
#                                                  url       date region  \
# 0  https://open.spotify.com/track/3a1lNhkSLSkpJE4... 2017-01-01     us
# 1  https://open.spotify.com/track/3a1lNhkSLSkpJE4... 2017-01-02     us
# 2  https://open.spotify.com/track/3a1lNhkSLSkpJE4... 2017-01-03     us
# 3  https://open.spotify.com/track/3a1lNhkSLSkpJE4... 2017-01-04     us
# 4  https://open.spotify.com/track/3a1lNhkSLSkpJE4... 2017-01-05     us
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.627   0.812  6.0    -4.215   1.0       0.0358         0.198
# 1         0.627   0.812  6.0    -4.215   1.0       0.0358         0.198
# ...

# %%
dfnew.columns
# Out:
# Index(['position', 'Track_Name', 'artist', 'streams', 'url', 'date', 'region',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
dftesttn.columns
# Out:
# Index(['Track_Name'], dtype='object')

# %%
#Now our training data has the same track names as our test data and we can model with validation data. 
#We want to model predictions regarding streams and position, respectively to time.
fig,ax= plt.subplots()
for n, group in dftrain.groupby('Track_Name'):
    group.plot(x='date',y='streams', ax=ax,label=n)
    
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=4, mode="expand", borderaxespad=1.)
plt.title('Scatterplot of Streams vs Time for Training Track Name')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Streams vs Time for Training Track Name')

# %%
fig,ax= plt.subplots()
for n, group in dftrain.groupby('Track_Name'):
    group.plot(x='date',y='position', ax=ax,label=n)
    plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=4, mode="expand", borderaxespad=1.)
plt.gca().invert_yaxis()
plt.title('Scatterplot of Position vs Time for Training Data Track Name')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Position vs Time for Training Data Track Name')

# %%
#Below is an exploration of the song features and their correlation to ranking and streams
x=dftrain['time_signature']
plt.hist(x, bins=10)
plt.gca().set(title='Time Signature in Ranking Data', ylabel='Frequency');

# %%
x=dftrain['instrumentalness']
plt.hist(x, bins=10)
plt.gca().set(title='Instrumentalness in Ranking Data', ylabel='Frequency');

# %%
x=dftrain['speechiness']
plt.hist(x, bins=10)
plt.gca().set(title='Speechiness in Ranking Data', ylabel='Frequency');

# %%
#Correlation Heatmap of song features by mexico, usa
corr = dftrain.corr()
corr.style.background_gradient(cmap='cool').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f92468d4_865f_11ea_9731_35388bce2573row0_col0 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }    #T_f92468d4_865f_11ea_9731_35388bce2573row0_col1 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }    #T_f92468d4_865f_11ea_9731_35388bce2573row0_col2 {
#             background-color:  #42bdff;
#             color:  #000000;
#         }    #T_f92468d4_865f_11ea_9731_35388bce2573row0_col3 {
#             background-color:  #3bc4ff;
#             color:  #000000;
#         }    #T_f92468d4_865f_11ea_9731_35388bce2573row0_col4 {
#             background-color:  #6996ff;
#             color:  #000000;
#         }    #T_f92468d4_865f_11ea_9731_35388bce2573row0_col5 {
#             background-color:  #0ef1ff;
#             color:  #000000;
#         }    #T_f92468d4_865f_11ea_9731_35388bce2573row0_col6 {
#             background-color:  #738cff;
#             color:  #000000;
# ...

# %%
dfin = dfnew.set_index('date')
dfin['streams'].plot(linewidth=0.5);

# %%
# format Sci-Notation to "1E4" to "1,000" for display 
pd.options.display.float_format = '{:,.0f}'.format

grouped = df[df.artist=='Post Malone'].groupby(['Track_Name'])

grouped['streams'].describe().sort_values(by='mean', ascending=False)
# Out:
#                          count      mean       std     min     25%       50%  \
# Track_Name
# rockstar                   214 1,135,131 1,010,576  49,611 171,683 1,261,426
# I Fall Apart               107   945,410   267,473 163,464 914,543 1,008,224
# Congratulations            597   494,676   386,275  39,031  65,017   635,132
# Candy Paint                219   406,222   266,210  43,253 203,983   259,244
# Go Flex                    362   281,776   107,536 144,845 217,827   237,096
# White Iverson              362   277,144    38,901 209,199 244,659   271,962
# No Option                  102   217,733    21,821 165,016 200,852   221,658
# Congratulations - Remix     30   210,078    38,835 146,824 173,488   207,290
# Deja Vu                    114   196,809    17,856 154,228 182,804   198,516
# rockstar - Remix            14    63,785     9,549  42,752  59,842    65,999
#
#                               75%       max
# Track_Name
# rockstar                2,095,082 2,905,678
# ...

# %%
plt.style.use('dark_background')
pd.options.display.float_format = '{:,.0f}'.format
colors = ['#191970','#001CF0','#0038E2','#0055D4','#0071C6','#008DB8','#00AAAA','#00C69C','#00E28E','#00FF80',]
explode = [0.7,0.5,0.3,0,0,0,0,0,0,.25]

plt.title('Post Malone\'s Top Songs by Total Streams from 2017', fontsize=18)
df[df['artist'] == 'Post Malone'].groupby('Track_Name').agg(np.sum)['streams'].sort_values().plot(kind='pie', colors=colors,
                explode=explode,
                  figsize=(6, 6),
                  autopct='%0.0f%%',
                  shadow=False)
plt.ylabel('')
plt.show()

# %%
df4 = df[df['region'].str.contains("mx")] #include only a region, Mexico

# %%
df4.artist.describe()
# Out:
# count          72384
# unique           372
# top       Ed Sheeran
# freq            1885
# Name: artist, dtype: object
